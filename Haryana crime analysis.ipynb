# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = pd.read_csv(r"C:\Users\user\Documents\32_Murder_victim_age_sex.csv")

# %%
data
# Out:
#                       Area_Name  Year               Group_Name  \
# 0     Andaman & Nicobar Islands  2001  Murder - Female Victims
# 1                Andhra Pradesh  2001  Murder - Female Victims
# 2             Arunachal Pradesh  2001  Murder - Female Victims
# 3                         Assam  2001  Murder - Female Victims
# 4                         Bihar  2001  Murder - Female Victims
# ...                         ...   ...                      ...
# 1013                 Tamil Nadu  2010   Murder - Total Victims
# 1014                    Tripura  2010   Murder - Total Victims
# 1015              Uttar Pradesh  2010   Murder - Total Victims
# 1016                Uttarakhand  2010   Murder - Total Victims
# 1017                West Bengal  2010   Murder - Total Victims
#
#          Sub_Group_Name  Victims_Above_50_Yrs  Victims_Total  \
# 0     2. Female Victims                   NaN              6
# 1     2. Female Victims                  67.0            607
# ...

# %%
data.head()
# Out:
#                    Area_Name  Year               Group_Name  \
# 0  Andaman & Nicobar Islands  2001  Murder - Female Victims
# 1             Andhra Pradesh  2001  Murder - Female Victims
# 2          Arunachal Pradesh  2001  Murder - Female Victims
# 3                      Assam  2001  Murder - Female Victims
# 4                      Bihar  2001  Murder - Female Victims
#
#       Sub_Group_Name  Victims_Above_50_Yrs  Victims_Total  \
# 0  2. Female Victims                   NaN              6
# 1  2. Female Victims                  67.0            607
# 2  2. Female Victims                   2.0             16
# 3  2. Female Victims                  11.0            128
# 4  2. Female Victims                  12.0            366
#
#    Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  Victims_Upto_15_18_Yrs  \
# 0                     NaN                  NaN                     NaN
# 1                    15.0                 38.0                    43.0
# ...

# %%
data.isnull().sum()
# Out:
# Area_Name                   0
# Year                        0
# Group_Name                  0
# Sub_Group_Name              0
# Victims_Above_50_Yrs       56
# Victims_Total               0
# Victims_Upto_10_15_Yrs    142
# Victims_Upto_10_Yrs       118
# Victims_Upto_15_18_Yrs    130
# Victims_Upto_18_30_Yrs      9
# Victims_Upto_30_50_Yrs     11
# dtype: int64

# %%
data = data.fillna(0)

# %%
data
# Out:
#                       Area_Name  Year               Group_Name  \
# 0     Andaman & Nicobar Islands  2001  Murder - Female Victims
# 1                Andhra Pradesh  2001  Murder - Female Victims
# 2             Arunachal Pradesh  2001  Murder - Female Victims
# 3                         Assam  2001  Murder - Female Victims
# 4                         Bihar  2001  Murder - Female Victims
# ...                         ...   ...                      ...
# 1013                 Tamil Nadu  2010   Murder - Total Victims
# 1014                    Tripura  2010   Murder - Total Victims
# 1015              Uttar Pradesh  2010   Murder - Total Victims
# 1016                Uttarakhand  2010   Murder - Total Victims
# 1017                West Bengal  2010   Murder - Total Victims
#
#          Sub_Group_Name  Victims_Above_50_Yrs  Victims_Total  \
# 0     2. Female Victims                   0.0              6
# 1     2. Female Victims                  67.0            607
# ...

# %%
data_Haryana = data[data["Area_Name"] == 'Haryana']

# %%
data_Haryana
# Out:
#     Area_Name  Year               Group_Name     Sub_Group_Name  \
# 10    Haryana  2001  Murder - Female Victims  2. Female Victims
# 45    Haryana  2002  Murder - Female Victims  2. Female Victims
# 78    Haryana  2003  Murder - Female Victims  2. Female Victims
# 112   Haryana  2004  Murder - Female Victims  2. Female Victims
# 144   Haryana  2005  Murder - Female Victims  2. Female Victims
# 179   Haryana  2006  Murder - Female Victims  2. Female Victims
# 213   Haryana  2007  Murder - Female Victims  2. Female Victims
# 247   Haryana  2008  Murder - Female Victims  2. Female Victims
# 282   Haryana  2009  Murder - Female Victims  2. Female Victims
# 315   Haryana  2010  Murder - Female Victims  2. Female Victims
# 348   Haryana  2001    Murder - Male Victims    1. Male Victims
# 382   Haryana  2002    Murder - Male Victims    1. Male Victims
# 416   Haryana  2003    Murder - Male Victims    1. Male Victims
# 450   Haryana  2004    Murder - Male Victims    1. Male Victims
# ...

# %%
data_Haryana = data_Haryana.set_index('Year')

# %%
data_Haryana
# Out:
#      Area_Name               Group_Name     Sub_Group_Name  \
# Year
# 2001   Haryana  Murder - Female Victims  2. Female Victims
# 2002   Haryana  Murder - Female Victims  2. Female Victims
# 2003   Haryana  Murder - Female Victims  2. Female Victims
# 2004   Haryana  Murder - Female Victims  2. Female Victims
# 2005   Haryana  Murder - Female Victims  2. Female Victims
# 2006   Haryana  Murder - Female Victims  2. Female Victims
# 2007   Haryana  Murder - Female Victims  2. Female Victims
# 2008   Haryana  Murder - Female Victims  2. Female Victims
# 2009   Haryana  Murder - Female Victims  2. Female Victims
# 2010   Haryana  Murder - Female Victims  2. Female Victims
# 2001   Haryana    Murder - Male Victims    1. Male Victims
# 2002   Haryana    Murder - Male Victims    1. Male Victims
# 2003   Haryana    Murder - Male Victims    1. Male Victims
# 2004   Haryana    Murder - Male Victims    1. Male Victims
# 2005   Haryana    Murder - Male Victims    1. Male Victims
# ...

# %%
data_Haryana.columns
# Out:
# Index(['Area_Name', 'Group_Name', 'Sub_Group_Name', 'Victims_Above_50_Yrs',
#        'Victims_Total', 'Victims_Upto_10_15_Yrs', 'Victims_Upto_10_Yrs',
#        'Victims_Upto_15_18_Yrs', 'Victims_Upto_18_30_Yrs',
#        'Victims_Upto_30_50_Yrs'],
#       dtype='object')

# %%
for i in data_Haryana.drop(['Area_Name', 'Group_Name', 'Sub_Group_Name'] , axis = 1).columns:
    data_Haryana[i].plot(kind = 'line')
    plt.title(i)
    plt.grid()
    plt.show()
